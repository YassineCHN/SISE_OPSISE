# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("C:/Users/ychen/Downloads/FW(1).csv")

# %%
print(df.head())
# Out:
#               datetime          ipsrc          ipdst  dstport proto  action  \
# 0  2026-03-02 15:39:53  192.168.107.2  192.168.107.5  37356.0   TCP    Deny
# 1  2026-03-02 15:39:54  192.168.107.2  192.168.107.5  37356.0   TCP    Deny
# 2  2026-03-02 15:39:55  192.168.107.2  192.168.107.5  37356.0   TCP    Deny
# 3  2026-03-02 15:39:55  192.168.107.2  192.168.107.5  37356.0   TCP    Deny
# 4  2026-03-02 15:39:55  192.168.107.6  192.168.107.5     22.0   TCP  Permit
#
#    policyid interface
# 0     999.0      eth0
# 1     999.0      eth0
# 2     999.0      eth0
# 3     999.0      eth0
# 4       1.0      eth0

# %%
df.shape
# Out:
# (15159, 8)

# %%
df["ipsrc"].value_counts()
# Out:
# ipsrc
# 192.168.107.2      7895
# 192.168.107.6      4759
# 192.168.107.1      1614
# 46.190.61.7         616
# 10.0.0.1             24
# 10.10.1.101          20
# 192.168.4.1          20
# 192.168.1.0          19
# 172.156.2.26         19
# 159.84.100.163       15
# 76.42.215.120        13
# 159.84.120.129       13
# 159.84.100.145       13
# 86.249.16.218        12
# 22.216.222.243       12
# 159.84.101.1         12
# 159.84.121.7         11
# 69.154.72.2          10
# 159.84.123.1          5
# 192.168.215.2         5
# 194.25.56.2           5
# 172.5.2.8             5
# 10.172.11.2           5
# 28.12.15.20           4
# 214.238.222.201       4
# 89.89.56.2            4
# 113.219.70.129        3
# 21.79.173.47          3
# 159.84.126.52         2
# 159.84.124.53         2
# 159.84.125.53         2
# 157.81.181.241        2
# 159.84.122.13         2
# 77.94.246.178         2
# 20.22.127.170         2
# Name: count, dtype: int64
